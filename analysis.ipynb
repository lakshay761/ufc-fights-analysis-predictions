# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import os

# %%
import seaborn as sns

# %%
df = pd.read_csv('data.csv')

# %%
df.columns
# Out:
# Index(['BPrev', 'BStreak', 'B_Age', 'B_Height', 'B_HomeTown', 'B_ID',
#        'B_Location', 'B_Name', 'B_Weight',
#        'B__Round1_Grappling_Reversals_Landed',
#        ...
#        'R__Round5_TIP_Ground Time', 'R__Round5_TIP_Guard Control Time',
#        'R__Round5_TIP_Half Guard Control Time',
#        'R__Round5_TIP_Misc. Ground Control Time',
#        'R__Round5_TIP_Mount Control Time', 'R__Round5_TIP_Neutral Time',
#        'R__Round5_TIP_Side Control Time', 'R__Round5_TIP_Standing Time',
#        'winby', 'winner'],
#       dtype='object', length=894)

# %% [markdown]
# Date
# Event_ID
# Fight_ID
# Last_round
# Max_round
# RPrev
# R_Age
# R_Height
# R_HomeTown
# R_ID
# R_Location
# R_Name
# R_Weight

# %%
df.size
# Out:
# 2072292

# %%
df = df.fillna(0)

# %%
df2 = df.loc[:,['BPrev','RPrev', 'BStreak', 'B_Age','R_Age', 'B_Height', 'B_HomeTown', 'B_ID',
       'B_Location', 'B_Name', 'B_Weight','Date','Event_ID','Fight_ID','Last_round','Max_round',
                'R_Height','R_HomeTown','R_ID','R_Location','R_Name','R_Weight','winby', 'winner']]

# %%
df2.head()
# Out:
#    BPrev  RPrev  BStreak  B_Age  R_Age  B_Height  \
# 0      0      0        0   38.0   39.0     193.0
# 1      0      0        0   36.0   32.0     172.0
# 2      0      0        0   39.0   31.0     167.0
# 3      0      0        0   33.0   37.0     167.0
# 4      0      0        0   36.0   37.0     185.0
#
#                         B_HomeTown  B_ID                       B_Location  \
# 0                 Hounslow England   808        Amsterdam The Netherlands
# 1  Chicago, Illinois United States  1054  Chicago, Illinois United States
# 2      Isla Vista , California USA   959       Sacramento, California USA
# 3                San Diego, CA USA  1056                San Diego, CA USA
# 4              Southampton England  2005              Southampton England
#
#              B_Name  ...    Last_round Max_round  R_Height  \
# 0  Alistair Overeem  ...             3         3     190.0
# 1     Ricardo Lamas  ...             5         5     170.0
# ...

# %%
df2.loc[(df2['BPrev'] > 1) & (df2['RPrev'] > 1)]
# Out:
#       BPrev  RPrev  BStreak  B_Age  R_Age  B_Height  \
# 338       2      2        1   33.0   34.0     172.0
# 352       2      2        0   38.0   31.0     170.0
# 353       2      2        0   26.0   34.0     170.0
# 373       2      2        2   32.0   38.0     170.0
# 381       2      2        1   34.0   30.0     177.0
# 387       2      2        1   33.0   36.0     162.0
# 389       3      2        1   29.0   33.0     177.0
# 408       2      2        2   31.0   36.0     167.0
# 424       2      2        1   31.0   25.0     177.0
# 434       2      4        2   29.0   35.0     177.0
# 446       2      2        0   33.0   40.0     167.0
# 458       2      2        1   39.0   33.0     185.0
# 459       2      2        2   31.0   27.0     187.0
# 466       2      2        0   33.0   32.0     162.0
# 468       3      2        1   31.0   34.0     175.0
# 480       2      2        2   35.0   40.0     187.0
# 482       2      2        2   33.0   32.0     175.0
# ...
